# %%
# !nvidia-smi
# Out:
# Fri Apr 11 10:42:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.120                Driver Version: 550.120        CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2060        Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   54C    P0             28W /   80W |       6MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # DATASET 1

# %%
from roboflow import Roboflow
rf = 
project = 
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=500 imgsz=640 batch=16 plots=True project=yolo_dataset_2 device=0
# Out:
# New https://pypi.org/project/ultralytics/8.3.107 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.105 🚀 Python-3.12.3 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060, 5920MiB)
# ...

# %% [markdown]
# # DATASET 2

# %%
from roboflow import Roboflow
rf =
project =
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=500 imgsz=640 batch=16 plots=True project=yolo_dataset_3
# Out:
# New https://pypi.org/project/ultralytics/8.3.107 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.105 🚀 Python-3.12.3 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2060, 5920MiB)
# ...
